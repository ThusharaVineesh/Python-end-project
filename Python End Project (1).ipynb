# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
df=pd.read_csv('myexcel - myexcel.csv.csv')

# %%
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.tail()
# Out:
#              Name       Team  Number Position  Age  Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz       8       PG   26  06-Mar     203  Butler
# 454     Raul Neto  Utah Jazz      25       PG   24  06-Jan     179     NaN
# 455  Tibor Pleiss  Utah Jazz      21        C   26  07-Mar     256     NaN
# 456   Jeff Withey  Utah Jazz      24        C   26     7-0     231  Kansas
# 457      Priyanka  Utah Jazz      34        C   25  07-Mar     231  Kansas
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457   947276.0

# %%
df.describe(include='all')
# Out:
#                  Name                  Team      Number Position         Age  \
# count             458                   458  458.000000      458  458.000000
# unique            458                    30         NaN        5         NaN
# top     Avery Bradley  New Orleans Pelicans         NaN       SG         NaN
# freq                1                    19         NaN      102         NaN
# mean              NaN                   NaN   17.713974      NaN   26.934498
# std               NaN                   NaN   15.966837      NaN    4.400128
# min               NaN                   NaN    0.000000      NaN   19.000000
# 25%               NaN                   NaN    5.000000      NaN   24.000000
# 50%               NaN                   NaN   13.000000      NaN   26.000000
# 75%               NaN                   NaN   25.000000      NaN   30.000000
# max               NaN                   NaN   99.000000      NaN   40.000000
#
# ...

# %%
df['height'] = np.random.randint(150, 181, size=len(df))
df['height'].describe()
# Out:
# count    458.000000
# mean     164.803493
# std        8.907047
# min      150.000000
# 25%      157.000000
# 50%      165.000000
# 75%      172.000000
# max      180.000000
# Name: height, dtype: float64

# %%
#insight:height column changed to a floate64 dtatype which has value between 150 and 180 from a object data type

# %%
r=df['Team'].value_counts()
r
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
plt.figure(figsize=(60,8))
plt.xlabel('Team')
plt.ylabel('Number of employees')
plt.title('Distribution of employees')
plt.bar(r.index,r.values)
plt.show()

# %%
#insight:New Orleans Pelicans  team has most number of players and the least was Orlando Magic,Minnesota Timberwolves both team have 14 number of employees,majority have same employees that is 15

# %%
percentage=(r/r.sum())*100

# %%
percentage
# Out:
# Team
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# Utah Jazz                 3.493450
# New York Knicks           3.493450
# Milwaukee Bucks           3.493450
# Brooklyn Nets             3.275109
# Portland Trail Blazers    3.275109
# Oklahoma City Thunder     3.275109
# Denver Nuggets            3.275109
# Washington Wizards        3.275109
# Miami Heat                3.275109
# Charlotte Hornets         3.275109
# Atlanta Hawks             3.275109
# San Antonio Spurs         3.275109
# Houston Rockets           3.275109
# Boston Celtics            3.275109
# Indiana Pacers            3.275109
# Detroit Pistons           3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# Sacramento Kings          3.275109
# Phoenix Suns              3.275109
# Los Angeles Lakers        3.275109
# Los Angeles Clippers      3.275109
# Golden State Warriors     3.275109
# Toronto Raptors           3.275109
# ...

# %%
plt.pie(r, labels=r.index)
plt.show()

# %%
#insight:piechart shows that the percentage split across various teams is almost same

# %%
#Segregate employees based on their positions within the company
p=df['Position'].value_counts()
p
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
plt.bar(p.index,p.values)
plt.xlabel('Positons')
plt.ylabel('Number of employees')
plt.title('Segration of employees')
plt.show()

# %%
#Insight:more employees have the position SG ,less employees are position c

# %%
df['Age'].describe()
# Out:
# count    458.000000
# mean      26.934498
# std        4.400128
# min       19.000000
# 25%       24.000000
# 50%       26.000000
# 75%       30.000000
# max       40.000000
# Name: Age, dtype: float64

# %%
plt.boxplot(df['Age'])
plt.show()

# %%
#insight:frombox plot we understood that majority of people is in age group 20 to 30,50% people are below 27,Oldest was 40 yougest was 19

# %%
salaryand_team=df.groupby('Team')['Salary'].sum()
highestsalary_team=salaryand_team.idxmax()
salaryand_position=df.groupby('Position')['Salary'].sum()
highestsalary_position=salaryand_position.idxmax()
print(f'Team which have highest salary expenditure: {highestsalary_team}')
print(f'Position which have highest salary expenditure: {highestsalary_position }')
# Out:
# Team which have highest salary expenditure: Cleveland Cavaliers
# Position which have highest salary expenditure: C

# %%
salaryand_team
# Out:
# Team
# Atlanta Hawks              72902950.0
# Boston Celtics             58541068.0
# Brooklyn Nets              52528475.0
# Charlotte Hornets          78340920.0
# Chicago Bulls              86783378.0
# Cleveland Cavaliers       106988689.0
# Dallas Mavericks           71198732.0
# Denver Nuggets             60121930.0
# Detroit Pistons            67168263.0
# Golden State Warriors      88868997.0
# Houston Rockets            75283021.0
# Indiana Pacers             66751826.0
# Los Angeles Clippers       94854640.0
# Los Angeles Lakers         71770431.0
# Memphis Grizzlies          76550880.0
# Miami Heat                 82515673.0
# Milwaukee Bucks            69603517.0
# Minnesota Timberwolves     59709697.0
# New Orleans Pelicans       82750774.0
# New York Knicks            73303898.0
# Oklahoma City Thunder      93765298.0
# Orlando Magic              60161470.0
# Philadelphia 76ers         30992894.0
# Phoenix Suns               63445135.0
# ...

# %%
plt.figure(figsize=(60,8))
plt.bar(salaryand_team.index,salaryand_team)
plt.xlabel('Team')
plt.ylabel('Salary')
plt.title('Highest Salary Expenditure by team')
plt.show()

# %%
#insight:Highest salary expentiure is in team Cleveland Cavaliers where as lowest is in Philadelphia 76ers

# %%
plt.bar(salaryand_position.index,salaryand_position)
plt.xlabel('Team')
plt.ylabel('Position')
plt.title('Highest Salary Expenditure by position')
plt.show()

# %%
#insight:Highest salary expentiure is positin in c,where lowest is in SG

# %%
sns.scatterplot(x="Age", y="Salary", data=df)
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("Scatter Plot Age vs Salary")
plt.show()

# %%
#insight:salary is heigher for age group 24 to 34,and minimum above 35 and below 25 just like gaussian distribution
